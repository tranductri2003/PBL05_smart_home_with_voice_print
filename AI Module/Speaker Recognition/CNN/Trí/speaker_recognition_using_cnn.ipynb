# %% [markdown]
# # Speaker Recognition
#
# **Author:** [Fadi Badine](https://twitter.com/fadibadine)<br>
# **Date created:** 14/06/2020<br>
# **Last modified:** 19/07/2023<br>
# **Description:** Classify speakers using Fast Fourier Transform (FFT) and a 1D Convnet.

# %% [markdown]
# ## Introduction
#
# This example demonstrates how to create a model to classify speakers from the
# frequency domain representation of speech recordings, obtained via Fast Fourier
# Transform (FFT).
#
# It shows the following:
#
# - How to use `tf.data` to load, preprocess and feed audio streams into a model
# - How to create a 1D convolutional network with residual
# connections for audio classification.
#
# Our process:
#
# - We prepare a dataset of speech samples from different speakers, with the speaker as label.
# - We add background noise to these samples to augment our data.
# - We take the FFT of these samples.
# - We train a 1D convnet to predict the correct speaker given a noisy FFT speech sample.
#
# Note:
#
# - This example should be run with TensorFlow 2.3 or higher, or `tf-nightly`.
# - The noise samples in the dataset need to be resampled to a sampling rate of 16000 Hz
# before using the code in this example. In order to do this, you will need to have
# installed `ffmpg`.

# %% [markdown]
# ## Setup

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import shutil
import numpy as np

import tensorflow as tf
import keras

from pathlib import Path
from IPython.display import display, Audio

# Get the data from https://www.kaggle.com/kongaevans/speaker-recognition-dataset/
# and save it to ./speaker-recognition-dataset.zip
# then unzip it to ./16000_pcm_speeches

# %%
# !kaggle datasets download -d kongaevans/speaker-recognition-dataset
# !unzip -qq speaker-recognition-dataset.zip

# %%
DATASET_ROOT = "our-voices"

# The folders in which we will put the audio samples and the noise samples
AUDIO_SUBFOLDER = "audio"
NOISE_SUBFOLDER = "noise"

DATASET_AUDIO_PATH = os.path.join(DATASET_ROOT, AUDIO_SUBFOLDER)
DATASET_NOISE_PATH = os.path.join(DATASET_ROOT, NOISE_SUBFOLDER)

# Percentage of samples to use for validation
VALID_SPLIT = 0.1

# Seed to use when shuffling the dataset and the noise
SHUFFLE_SEED = 43

# The sampling rate to use.
# This is the one used in all the audio samples.
# We will resample all the noise to this sampling rate.
# This will also be the output size of the audio wave samples
# (since all samples are of 1 second long)
SAMPLING_RATE = 16000

# The factor to multiply the noise with according to:
#   noisy_sample = sample + noise * prop * scale
#      where prop = sample_amplitude / noise_amplitude
SCALE = 0.5

BATCH_SIZE = 128
EPOCHS = 100  # For a real training run, use EPOCHS = 100

# %% [markdown]
# ## Data preparation
#
# The dataset is composed of 7 folders, divided into 2 groups:
#
# - Speech samples, with 5 folders for 5 different speakers. Each folder contains
# 1500 audio files, each 1 second long and sampled at 16000 Hz.
# - Background noise samples, with 2 folders and a total of 6 files. These files
# are longer than 1 second (and originally not sampled at 16000 Hz, but we will resample them to 16000 Hz).
# We will use those 6 files to create 354 1-second-long noise samples to be used for training.
#
# Let's sort these 2 categories into 2 folders:
#
# - An `audio` folder which will contain all the per-speaker speech sample folders
# - A `noise` folder which will contain all the noise samples

# %% [markdown]
# Before sorting the audio and noise categories into 2 folders,
# we have the following directory structure:
#
# ```
# main_directory/
# ...speaker_a/
# ...speaker_b/
# ...speaker_c/
# ...speaker_d/
# ...speaker_e/
# ...other/
# ..._background_noise_/
# ```
#
# After sorting, we end up with the following structure:
#
# ```
# main_directory/
# ...audio/
# ......speaker_a/
# ......speaker_b/
# ......speaker_c/
# ......speaker_d/
# ......speaker_e/
# ...noise/
# ......other/
# ......_background_noise_/
# ```

# %%
for folder in os.listdir(DATASET_ROOT):
    if os.path.isdir(os.path.join(DATASET_ROOT, folder)):
        if folder in [AUDIO_SUBFOLDER, NOISE_SUBFOLDER]:
            # If folder is `audio` or `noise`, do nothing
            continue
        elif folder in ["other", "_background_noise_"]:
            # If folder is one of the folders that contains noise samples,
            # move it to the `noise` folder
            shutil.move(
                os.path.join(DATASET_ROOT, folder),
                os.path.join(DATASET_NOISE_PATH, folder),
            )
        else:
            # Otherwise, it should be a speaker folder, then move it to
            # `audio` folder
            shutil.move(
                os.path.join(DATASET_ROOT, folder),
                os.path.join(DATASET_AUDIO_PATH, folder),
            )

# %% [markdown]
# ## Noise preparation
#
# In this section:
#
# - We load all noise samples (which should have been resampled to 16000)
# - We split those noise samples to chunks of 16000 samples which
# correspond to 1 second duration each

# %%
# Get the list of all noise files
noise_paths = []
for subdir in os.listdir(DATASET_NOISE_PATH):
    subdir_path = Path(DATASET_NOISE_PATH) / subdir
    if os.path.isdir(subdir_path):
        noise_paths += [
            os.path.join(subdir_path, filepath)
            for filepath in os.listdir(subdir_path)
            if filepath.endswith(".wav")
        ]
if not noise_paths:
    raise RuntimeError(f"Could not find any files at {DATASET_NOISE_PATH}")
print(
    "Found {} files belonging to {} directories".format(
        len(noise_paths), len(os.listdir(DATASET_NOISE_PATH))
    )
)
# Out:
# Found 6 files belonging to 2 directories

# %% [markdown]
# Resample all noise samples to 16000 Hz

# %%
import subprocess
import os
import tensorflow as tf

DATASET_NOISE_PATH = 'our-voices/noise'  # Hãy thay thế bằng đường dẫn thực tế của dữ liệu
SAMPLING_RATE = 16000

def convert_sample_rate(input_path, output_path, target_sample_rate=16000):
    command = ['ffmpeg', '-hide_banner', '-loglevel', 'panic', '-y', '-i', input_path, '-ar', str(target_sample_rate), output_path]
    subprocess.run(command, check=True)

# Duyệt qua cấu trúc thư mục và chuyển đổi mỗi tệp
for root, dirs, files in os.walk(DATASET_NOISE_PATH):
    for file in files:
        if file.endswith('.wav'):
            file_path = os.path.join(root, file)
            # print(file_path)
            # Lưu tạm thời tệp đã chuyển đổi
            temp_path = file_path + '.temp.wav'
            convert_sample_rate(file_path, temp_path, SAMPLING_RATE)
            # Thay thế tệp gốc bằng tệp đã chuyển đổi
            os.replace(temp_path, file_path)

print("Hoàn thành chuyển đổi.")
# Out:
# Hoàn thành chuyển đổi.

# %%
import subprocess
import os
import tensorflow as tf

DATASET_AUDIO_PATH = 'our-voices/audio'  # Hãy thay thế bằng đường dẫn thực tế của dữ liệu
SAMPLING_RATE = 16000

def convert_sample_rate(input_path, output_path, target_sample_rate=16000):
    command = ['ffmpeg', '-hide_banner', '-loglevel', 'panic', '-y', '-i', input_path, '-ar', str(target_sample_rate), output_path]
    subprocess.run(command, check=True)

# Duyệt qua cấu trúc thư mục và chuyển đổi mỗi tệp
for root, dirs, files in os.walk(DATASET_AUDIO_PATH):
    for file in files:
        if file.endswith('.wav'):
            file_path = os.path.join(root, file)
            # print(file_path)
            # Lưu tạm thời tệp đã chuyển đổi
            temp_path = file_path + '.temp.wav'
            convert_sample_rate(file_path, temp_path, SAMPLING_RATE)
            # Thay thế tệp gốc bằng tệp đã chuyển đổi
            os.replace(temp_path, file_path)

print("Hoàn thành chuyển đổi.")
# Out:
# Hoàn thành chuyển đổi.

# %%
command = (
    "for dir in `ls -1 " + DATASET_NOISE_PATH + "`; do "
    "for file in `ls -1 " + DATASET_NOISE_PATH + "/$dir/*.wav`; do "
    "sample_rate=`ffprobe -hide_banner -loglevel panic -show_streams "
    "$file | grep sample_rate | cut -f2 -d=`; "
    "if [ $sample_rate -ne 16000 ]; then "
    "ffmpeg -hide_banner -loglevel panic -y "
    "-i $file -ar 16000 temp.wav; "
    "mv temp.wav $file; "
    "fi; done; done"
)
os.system(command)


# Split noise into chunks of 16,000 steps each
def load_noise_sample(path):
    sample, sampling_rate = tf.audio.decode_wav(
        tf.io.read_file(path), desired_channels=1
    )
    print(f"\033[91mPath: {path} sampling_rate: {sampling_rate} SAMPLING_RATE: {SAMPLING_RATE}\033[0m")

    if sampling_rate == SAMPLING_RATE:
        # Number of slices of 16000 each that can be generated from the noise sample
        slices = int(sample.shape[0] / SAMPLING_RATE)
        sample = tf.split(sample[: slices * SAMPLING_RATE], slices)
        return sample
    else:
        print("Sampling rate for {} is incorrect. Ignoring it".format(path))
        return None


noises = []
for path in noise_paths:
    sample = load_noise_sample(path)
    if sample:
        noises.extend(sample)
noises = tf.stack(noises)

print(
    "{} noise files were split into {} noise samples where each is {} sec. long".format(
        len(noise_paths), noises.shape[0], noises.shape[1] // SAMPLING_RATE
    )
)
# Out:
# Path: our-voices\noise\other\exercise_bike.wav sampling_rate: 16000 SAMPLING_RATE: 16000
# Path: our-voices\noise\other\pink_noise.wav sampling_rate: 16000 SAMPLING_RATE: 16000
# Path: our-voices\noise\_background_noise_\10convert.com_Audience-Claps_daSG5fwdA7o.wav sampling_rate: 16000 SAMPLING_RATE: 16000
# Path: our-voices\noise\_background_noise_\doing_the_dishes.wav sampling_rate: 16000 SAMPLING_RATE: 16000
# Path: our-voices\noise\_background_noise_\dude_miaowing.wav sampling_rate: 16000 SAMPLING_RATE: 16000
# Path: our-voices\noise\_background_noise_\running_tap.wav sampling_rate: 16000 SAMPLING_RATE: 16000
# 6 noise files were split into 354 noise samples where each is 1 sec. long

# %% [markdown]
# ## Dataset generation

# %%
def paths_and_labels_to_dataset(audio_paths, labels):
    """Constructs a dataset of audios and labels."""
    path_ds = tf.data.Dataset.from_tensor_slices(audio_paths)
    audio_ds = path_ds.map(
        lambda x: path_to_audio(x), num_parallel_calls=tf.data.AUTOTUNE
    )
    label_ds = tf.data.Dataset.from_tensor_slices(labels)
    return tf.data.Dataset.zip((audio_ds, label_ds))


def path_to_audio(path):
    """Reads and decodes an audio file."""
    audio = tf.io.read_file(path)
    audio, _ = tf.audio.decode_wav(audio, 1, SAMPLING_RATE)
    return audio


def add_noise(audio, noises=None, scale=0.5):
    if noises is not None:
        # Create a random tensor of the same size as audio ranging from
        # 0 to the number of noise stream samples that we have.
        tf_rnd = tf.random.uniform(
            (tf.shape(audio)[0],), 0, noises.shape[0], dtype=tf.int32
        )
        noise = tf.gather(noises, tf_rnd, axis=0)

        # Get the amplitude proportion between the audio and the noise
        prop = tf.math.reduce_max(audio, axis=1) / tf.math.reduce_max(noise, axis=1)
        prop = tf.repeat(tf.expand_dims(prop, axis=1), tf.shape(audio)[1], axis=1)

        # Adding the rescaled noise to audio
        audio = audio + noise * prop * scale

    return audio


def audio_to_fft(audio):
    # Since tf.signal.fft applies FFT on the innermost dimension,
    # we need to squeeze the dimensions and then expand them again
    # after FFT
    audio = tf.squeeze(audio, axis=-1)
    fft = tf.signal.fft(
        tf.cast(tf.complex(real=audio, imag=tf.zeros_like(audio)), tf.complex64)
    )
    fft = tf.expand_dims(fft, axis=-1)

    # Return the absolute value of the first half of the FFT
    # which represents the positive frequencies
    return tf.math.abs(fft[:, : (audio.shape[1] // 2), :])


# Get the list of audio file paths along with their corresponding labels

class_names = os.listdir(DATASET_AUDIO_PATH)
print(
    "Our class names: {}".format(
        class_names,
    )
)

audio_paths = []
labels = []
for label, name in enumerate(class_names):
    print(
        "Processing speaker {}".format(
            name,
        )
    )
    dir_path = Path(DATASET_AUDIO_PATH) / name
    speaker_sample_paths = [
        os.path.join(dir_path, filepath)
        for filepath in os.listdir(dir_path)
        if filepath.endswith(".wav")
    ]
    audio_paths += speaker_sample_paths
    labels += [label] * len(speaker_sample_paths)

print(
    "Found {} files belonging to {} classes.".format(len(audio_paths), len(class_names))
)

# Shuffle
rng = np.random.RandomState(SHUFFLE_SEED)
rng.shuffle(audio_paths)
rng = np.random.RandomState(SHUFFLE_SEED)
rng.shuffle(labels)

# Split into training and validation
num_val_samples = int(VALID_SPLIT * len(audio_paths))
print("Using {} files for training.".format(len(audio_paths) - num_val_samples))
train_audio_paths = audio_paths[:-num_val_samples]
train_labels = labels[:-num_val_samples]

print("Using {} files for validation.".format(num_val_samples))
valid_audio_paths = audio_paths[-num_val_samples:]
valid_labels = labels[-num_val_samples:]

# Create 2 datasets, one for training and the other for validation
train_ds = paths_and_labels_to_dataset(train_audio_paths, train_labels)
train_ds = train_ds.shuffle(buffer_size=BATCH_SIZE * 8, seed=SHUFFLE_SEED).batch(
    BATCH_SIZE
)

valid_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels)
valid_ds = valid_ds.shuffle(buffer_size=32 * 8, seed=SHUFFLE_SEED).batch(32)


# Add noise to the training set
train_ds = train_ds.map(
    lambda x, y: (add_noise(x, noises, scale=SCALE), y),
    num_parallel_calls=tf.data.AUTOTUNE,
)

# Transform audio wave to the frequency domain using `audio_to_fft`
train_ds = train_ds.map(
    lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.AUTOTUNE
)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)

valid_ds = valid_ds.map(
    lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.AUTOTUNE
)
valid_ds = valid_ds.prefetch(tf.data.AUTOTUNE)
# Out:
# Our class names: ['Phát', 'Trí', 'Tuấn', 'Đạt']
# Processing speaker Phát
# Processing speaker Trí
# Processing speaker Tuấn
# Processing speaker Đạt
# Found 898 files belonging to 4 classes.
# Using 809 files for training.
# Using 89 files for validation.

# %% [markdown]
# ## Model Definition

# %%
def residual_block(x, filters, conv_num=3, activation="relu"):
    # Shortcut
    s = keras.layers.Conv1D(filters, 1, padding="same")(x)
    for i in range(conv_num - 1):
        x = keras.layers.Conv1D(filters, 3, padding="same")(x)
        x = keras.layers.Activation(activation)(x)
    x = keras.layers.Conv1D(filters, 3, padding="same")(x)
    x = keras.layers.Add()([x, s])
    x = keras.layers.Activation(activation)(x)
    return keras.layers.MaxPool1D(pool_size=2, strides=2)(x)


def build_model(input_shape, num_classes):
    inputs = keras.layers.Input(shape=input_shape, name="input")

    x = residual_block(inputs, 16, 2)
    x = residual_block(x, 32, 2)
    x = residual_block(x, 64, 3)
    x = residual_block(x, 128, 3)
    x = residual_block(x, 128, 3)

    x = keras.layers.AveragePooling1D(pool_size=3, strides=3)(x)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(256, activation="relu")(x)
    x = keras.layers.Dense(128, activation="relu")(x)

    outputs = keras.layers.Dense(num_classes, activation="softmax", name="output")(x)

    return keras.models.Model(inputs=inputs, outputs=outputs)


model = build_model((SAMPLING_RATE // 2, 1), len(class_names))

model.summary()

# Compile the model using Adam's default learning rate
model.compile(
    optimizer="Adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# Add callbacks:
# 'EarlyStopping' to stop training when the model is not enhancing anymore
# 'ModelCheckPoint' to always keep the model that has the best val_accuracy
model_save_filename = "model.keras"

earlystopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
mdlcheckpoint_cb = keras.callbacks.ModelCheckpoint(
    model_save_filename, monitor="val_accuracy", save_best_only=True
)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 8000, 1)   │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 8000, 16)  │         64 │ input[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 8000, 16)  │          0 │ conv1d_1[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 8000, 16)  │        784 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 8000, 16)  │         32 │ input[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 8000, 16)  │          0 │ conv1d_2[0][0],   │
# │                     │                   │            │ conv1d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 8000, 16)  │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 4000, 16)  │          0 │ activation_1[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 4000, 32)  │      1,568 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 4000, 32)  │          0 │ conv1d_4[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 4000, 32)  │      3,104 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 4000, 32)  │        544 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 4000, 32)  │          0 │ conv1d_5[0][0],   │
# │                     │                   │            │ conv1d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 4000, 32)  │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 2000, 32)  │          0 │ activation_3[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 2000, 64)  │      6,208 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 2000, 64)  │          0 │ conv1d_7[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_8 (Conv1D)   │ (None, 2000, 64)  │     12,352 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 2000, 64)  │          0 │ conv1d_8[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_9 (Conv1D)   │ (None, 2000, 64)  │     12,352 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 2000, 64)  │      2,112 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 2000, 64)  │          0 │ conv1d_9[0][0],   │
# │                     │                   │            │ conv1d_6[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 2000, 64)  │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_2     │ (None, 1000, 64)  │          0 │ activation_6[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_11 (Conv1D)  │ (None, 1000, 128) │     24,704 │ max_pooling1d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 1000, 128) │          0 │ conv1d_11[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_12 (Conv1D)  │ (None, 1000, 128) │     49,280 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 1000, 128) │          0 │ conv1d_12[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_13 (Conv1D)  │ (None, 1000, 128) │     49,280 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_10 (Conv1D)  │ (None, 1000, 128) │      8,320 │ max_pooling1d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 1000, 128) │          0 │ conv1d_13[0][0],  │
# │                     │                   │            │ conv1d_10[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 1000, 128) │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_3     │ (None, 500, 128)  │          0 │ activation_9[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_15 (Conv1D)  │ (None, 500, 128)  │     49,280 │ max_pooling1d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 500, 128)  │          0 │ conv1d_15[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_16 (Conv1D)  │ (None, 500, 128)  │     49,280 │ activation_10[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 500, 128)  │          0 │ conv1d_16[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_17 (Conv1D)  │ (None, 500, 128)  │     49,280 │ activation_11[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_14 (Conv1D)  │ (None, 500, 128)  │     16,512 │ max_pooling1d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 500, 128)  │          0 │ conv1d_17[0][0],  │
# │                     │                   │            │ conv1d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 500, 128)  │          0 │ add_4[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_4     │ (None, 250, 128)  │          0 │ activation_12[0]… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling1d   │ (None, 83, 128)   │          0 │ max_pooling1d_4[… │
# │ (AveragePooling1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 10624)     │          0 │ average_pooling1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │  2,720,000 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │     32,896 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 4)         │        516 │ dense_1[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,088,468 (11.78 MB)
#  Trainable params: 3,088,468 (11.78 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training

# %%
import os

dataset_noise_path = 'our-voices/audio'
wav_files = [os.path.join(root, name)
             for root, dirs, files in os.walk(dataset_noise_path)
             for name in files
             if name.endswith(".wav")]

print(f"Tổng số tệp WAV: {len(wav_files)}")

import subprocess

def check_file_format_and_sample_rate(file_path):
    try:
        # Lấy thông tin định dạng
        format_output = subprocess.check_output(['ffprobe', '-v', 'error', '-select_streams', 'a:0',
                                                 '-show_entries', 'stream=sample_rate', '-of', 'default=noprint_wrappers=1:nokey=1',
                                                 file_path], text=True)
        return format_output.strip()
    except subprocess.CalledProcessError as e:
        print(f"Không thể kiểm tra tệp: {file_path}")
        return None

# Kiểm tra từng tệp
for wav_file in wav_files:
    sample_rate = check_file_format_and_sample_rate(wav_file)
    print(f"Tệp: {wav_file}, Tốc độ lấy mẫu: {sample_rate}")


import tensorflow as tf

def test_read_wav(file_path):
    # Đọc tệp WAV
    raw_audio = tf.io.read_file(file_path)
    audio, sample_rate = tf.audio.decode_wav(raw_audio)
    print(f"Đọc thành công tệp: {file_path}, Tốc độ lấy mẫu: {sample_rate.numpy()}")

# Thử đọc một tệp mẫu
test_read_wav(wav_files[0])
# Out:
# Tổng số tệp WAV: 898
# Tệp: our-voices/audio\Phát\phat_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_10_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_1_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_2_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_3_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_4_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_5_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_6_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_21.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_7_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_8_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Phát\phat_9_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_10_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_21.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_22.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_1_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_2_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_3_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_4_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_5_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_21.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_6_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_7_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_8_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Trí\tri_9_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_21.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_22.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_0_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_1_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_2_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_3_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_21.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_22.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_23.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_4_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_21.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_5_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_21.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_22.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_23.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_24.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_25.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_6_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_21.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_7_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_21.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_8_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_21.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Tuấn\tuan_9_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_21.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_22.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_23.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_10_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_1_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_2_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_21.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_3_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_4_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_5_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_21.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_22.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_23.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_6_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_21.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_7_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_21.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_22.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_8_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_0.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_1.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_10.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_11.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_12.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_13.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_14.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_15.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_16.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_17.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_18.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_19.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_2.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_20.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_21.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_3.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_4.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_5.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_6.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_7.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_8.wav, Tốc độ lấy mẫu: 16000
# Tệp: our-voices/audio\Đạt\dat_9_9.wav, Tốc độ lấy mẫu: 16000
# Đọc thành công tệp: our-voices/audio\Phát\phat_1.wav, Tốc độ lấy mẫu: 16000

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=valid_ds,
    callbacks=[earlystopping_cb, mdlcheckpoint_cb],
)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.2074 - loss: 2.6011 - val_accuracy: 0.5056 - val_loss: 1.2801
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.4121 - loss: 1.2668 - val_accuracy: 0.3708 - val_loss: 1.2534
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5668 - loss: 1.0807 - val_accuracy: 0.5843 - val_loss: 1.0418
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.6542 - loss: 0.9464 - val_accuracy: 0.7079 - val_loss: 0.9113
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7069 - loss: 0.8208 - val_accuracy: 0.7191 - val_loss: 0.9355
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7400 - loss: 0.7055 - val_accuracy: 0.7191 - val_loss: 0.8151
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7651 - loss: 0.6205 - val_accuracy: 0.5281 - val_loss: 1.7830
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.6925 - loss: 0.8288 - val_accuracy: 0.7640 - val_loss: 0.6853
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7756 - loss: 0.6499 - val_accuracy: 0.7865 - val_loss: 0.7005
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7899 - loss: 0.5582 - val_accuracy: 0.7528 - val_loss: 0.7217
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8031 - loss: 0.5421 - val_accuracy: 0.7753 - val_loss: 0.6801
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8348 - loss: 0.4308 - val_accuracy: 0.7865 - val_loss: 0.5453
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8350 - loss: 0.4096 - val_accuracy: 0.7865 - val_loss: 0.5140
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8476 - loss: 0.3921 - val_accuracy: 0.8315 - val_loss: 0.4956
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8912 - loss: 0.3214 - val_accuracy: 0.8315 - val_loss: 0.4961
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8589 - loss: 0.3515 - val_accuracy: 0.8539 - val_loss: 0.3715
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8848 - loss: 0.3222 - val_accuracy: 0.8652 - val_loss: 0.3113
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8693 - loss: 0.3219 - val_accuracy: 0.8764 - val_loss: 0.2949
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9133 - loss: 0.2331 - val_accuracy: 0.8652 - val_loss: 0.3644
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8949 - loss: 0.2658 - val_accuracy: 0.8539 - val_loss: 0.4007
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9021 - loss: 0.2445 - val_accuracy: 0.8539 - val_loss: 0.3726
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9318 - loss: 0.1637 - val_accuracy: 0.8427 - val_loss: 0.5961
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9360 - loss: 0.1852 - val_accuracy: 0.8989 - val_loss: 0.3789
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9483 - loss: 0.1348 - val_accuracy: 0.9101 - val_loss: 0.2919
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9399 - loss: 0.1794 - val_accuracy: 0.8652 - val_loss: 0.3611
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9534 - loss: 0.1382 - val_accuracy: 0.8876 - val_loss: 0.2692
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9402 - loss: 0.1584 - val_accuracy: 0.8876 - val_loss: 0.3855
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9557 - loss: 0.1608 - val_accuracy: 0.8427 - val_loss: 0.4556
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9417 - loss: 0.1609 - val_accuracy: 0.9101 - val_loss: 0.2252
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9622 - loss: 0.1220 - val_accuracy: 0.8989 - val_loss: 0.3032
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9563 - loss: 0.1152 - val_accuracy: 0.8876 - val_loss: 0.5139
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9501 - loss: 0.1430 - val_accuracy: 0.8427 - val_loss: 0.6389
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9252 - loss: 0.1962 - val_accuracy: 0.9438 - val_loss: 0.1746
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9505 - loss: 0.1595 - val_accuracy: 0.8989 - val_loss: 0.3347
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9465 - loss: 0.1421 - val_accuracy: 0.9101 - val_loss: 0.2978
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9418 - loss: 0.1547 - val_accuracy: 0.8989 - val_loss: 0.5953
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9505 - loss: 0.1318 - val_accuracy: 0.8652 - val_loss: 0.5769
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9464 - loss: 0.1433 - val_accuracy: 0.9326 - val_loss: 0.2772
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9603 - loss: 0.1175 - val_accuracy: 0.8989 - val_loss: 0.5611
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9745 - loss: 0.0866 - val_accuracy: 0.8876 - val_loss: 0.5297
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9753 - loss: 0.0702 - val_accuracy: 0.9213 - val_loss: 0.5041
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9658 - loss: 0.0845 - val_accuracy: 0.8989 - val_loss: 0.4660
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9718 - loss: 0.1047 - val_accuracy: 0.8876 - val_loss: 0.4556

# %% [markdown]
# ## Evaluation

# %%
print(model.evaluate(valid_ds))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 0.9446 - loss: 0.1606
# [0.16722077131271362, 0.9438202381134033]

# %% [markdown]
# We get ~ 98% validation accuracy.

# %% [markdown]
# ## Demonstration
#
# Let's take some samples and:
#
# - Predict the speaker
# - Compare the prediction with the real speaker
# - Listen to the audio to see that despite the samples being noisy,
# the model is still pretty accurate

# %%
SAMPLES_TO_DISPLAY = 10

test_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels)
test_ds = test_ds.shuffle(buffer_size=BATCH_SIZE * 8, seed=SHUFFLE_SEED).batch(
    BATCH_SIZE
)

test_ds = test_ds.map(
    lambda x, y: (add_noise(x, noises, scale=SCALE), y),
    num_parallel_calls=tf.data.AUTOTUNE,
)

for audios, labels in test_ds.take(1):
    # Get the signal FFT
    ffts = audio_to_fft(audios)
    # Predict
    y_pred = model.predict(ffts)
    
    # Lấy số lượng mẫu thực tế trong batch hiện tại
    actual_batch_size = audios.shape[0]
    
    # Tạo chỉ số mẫu ngẫu nhiên dựa trên kích thước thực tế của batch
    rnd = np.random.randint(0, actual_batch_size, SAMPLES_TO_DISPLAY)
    
    audios = audios.numpy()[rnd, :, :]
    labels = labels.numpy()[rnd]
    y_pred = np.argmax(y_pred, axis=-1)[rnd]

    for index in range(SAMPLES_TO_DISPLAY):
        # For every sample, print the true and predicted label
        # as well as run the voice with the noise
        print(
            "Speaker:\33{} {}\33[0m\tPredicted:\33{} {}\33[0m".format(
                "[92m" if labels[index] == y_pred[index] else "[91m",
                class_names[labels[index]],
                "[92m" if labels[index] == y_pred[index] else "[91m",
                class_names[y_pred[index]],
            )
        )
        display(Audio(audios[index, :, :].squeeze(), rate=SAMPLING_RATE))
        
        
        

# SAMPLES_TO_DISPLAY = 10

# test_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels)
# test_ds = test_ds.shuffle(buffer_size=BATCH_SIZE * 8, seed=SHUFFLE_SEED).batch(
#     BATCH_SIZE
# )

# test_ds = test_ds.map(
#     lambda x, y: (add_noise(x, noises, scale=SCALE), y),
#     num_parallel_calls=tf.data.AUTOTUNE,
# )

# for audios, labels in test_ds.take(1):
#     # Get the signal FFT
#     ffts = audio_to_fft(audios)
#     # Predict
#     y_pred = model.predict(ffts)
#     # Take random samples
#     rnd = np.random.randint(0, BATCH_SIZE, SAMPLES_TO_DISPLAY)
#     audios = audios.numpy()[rnd, :, :]
#     labels = labels.numpy()[rnd]
#     y_pred = np.argmax(y_pred, axis=-1)[rnd]

#     for index in range(SAMPLES_TO_DISPLAY):
#         # For every sample, print the true and predicted label
#         # as well as run the voice with the noise
#         print(
#             "Speaker:\33{} {}\33[0m\tPredicted:\33{} {}\33[0m".format(
#                 "[92m" if labels[index] == y_pred[index] else "[91m",
#                 class_names[labels[index]],
#                 "[92m" if labels[index] == y_pred[index] else "[91m",
#                 class_names[y_pred[index]],
#             )
#         )
#         display(Audio(audios[index, :, :].squeeze(), rate=SAMPLING_RATE))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Speaker: Tuấn	Predicted: Tuấn
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Đạt	Predicted: Đạt
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Tuấn	Predicted: Tuấn
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Đạt	Predicted: Đạt
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Đạt	Predicted: Đạt
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Phát	Predicted: Phát
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Phát	Predicted: Phát
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Phát	Predicted: Phát
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Tuấn	Predicted: Phát
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Đạt	Predicted: Đạt
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
